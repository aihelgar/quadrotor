# %%
# Online Python - IDE, Editor, Compiler, Interpreter
'''
def sum(a, b):
    return (a + b)

a = int(input('Enter 1st number: '))
b = int(input('Enter 2nd number: '))

print(f'Sum of {a} and {b} is {sum(a, b)}')

'''

import numpy as np
import matplotlib.pyplot as plt

A = np.array([[0, 5, 0], 
              [-2, 6, 5], 
              [8, 7, 6]])
y = np.array([2, 4, -3])

#x = np.linalg.solve(A, y)
#print(x)

norm_max = max(np.max(A),np.max(y))
A = np.divide(A,norm_max)
y = np.divide(y,norm_max)
print(A)
print(y)

x = np.linalg.solve(A, y)
print('answer', x)

plt.plot(A)
# Out:
# [[ 0.     0.625  0.   ]
#  [-0.25   0.75   0.625]
#  [ 1.     0.875  0.75 ]]
# [ 0.25   0.5   -0.375]
# answer [-0.74230769  0.4         0.02307692]
# [<matplotlib.lines.Line2D at 0x63ed9a0>,
#  <matplotlib.lines.Line2D at 0x63eda00>,
#  <matplotlib.lines.Line2D at 0x63edb20>]
